# %% [markdown]
# GOOGLE -> Networkx_reference.pdf

# %%
# %magic?

# %% [markdown]
# ### A.1 Creating a graph

# %%
import networkx as nx

# %%
G = nx.Graph()

# %% [markdown]
# ### A.2 Nodes

# %%
# 添加一个节点
G.add_node(1)

# %%
# 添加一组节点
G.add_nodes_from([2, 3])

# %%
H = nx.path_graph(10)
H

# %%
G.add_nodes_from(H)

# %%
G.nodes
# Out:
# NodeView((1, 2, 3, 0, 4, 5, 6, 7, 8, 9))

# %%
G.node
# Out:
# NodeView((1, 2, 3, 0, 4, 5, 6, 7, 8, 9))

# %% [markdown]
# ### A.3 Edges

# %%
#  一次添加一条边
G.add_edge(1, 2)

# %%
# 需要添加*号，解开edge tuple
e = (2, 3)
G.add_edge(*e)

# %%
# 一次添加一组边
G.add_edges_from([(1, 2), (1, 3)])

# %%
G.add_edges_from(H.edges)

# %%
# 清空
G.clear()

# %%
G.edges
# Out:
# EdgeView([])

# %%
G.nodes
# Out:
# NodeView(())

# %%
G.add_edges_from([(1, 2), (1, 3)])
G.add_node(1)
G.add_edge(1, 2)
G.add_node("spam") # 添加节点 "spam"
G.add_nodes_from("spam") # 添加4个节点 "s", "p", "a", "m"
G.add_edge(3, "m")

# %% [markdown]
# These are set-like views of the nodes, edges, neighbors (adjacencies), and degrees of nodes in a graph.

# %%
G.edges
# Out:
# EdgeView([(1, 2), (1, 3), (3, 'm')])

# %%
G.nodes
# Out:
# NodeView((1, 2, 3, 'spam', 's', 'p', 'a', 'm'))

# %%
# 变成list
list(G.nodes)
# Out:
# [1, 2, 3, 'spam', 's', 'p', 'a', 'm']

# %%
list(G.edges)
# Out:
# [(1, 2), (1, 3), (3, 'm')]

# %%
# 列出他们的相邻节点
list(G.adj[1])
# Out:
# [2, 3]

# %%
list(G.neighbors(1))
# Out:
# [2, 3]

# %%
G.degree[1]
# Out:
# 2

# %%
G.edges([2, 'm'])
# Out:
# EdgeDataView([(2, 1), ('m', 3)])

# %%
for i in list(G.nodes):
    print(G.edges([i]))
# Out:
# [(1, 2), (1, 3)]
# [(2, 1)]
# [(3, 1), (3, 'm')]
# []
# []
# []
# []
# [('m', 3)]

# %%
# 去掉nodes, 去掉edges from the graph in a similar fashion to adding.
G.nodes
# Out:
# NodeView((1, 2, 3, 'spam', 's', 'p', 'a', 'm'))

# %%
G.edges
# Out:
# EdgeView([(1, 2), (1, 3), (3, 'm')])

# %%
G.remove_node('spam')

# %%
G.remove_edge(1,3)

# %%
G.edges
# Out:
# EdgeView([(1, 2), (3, 'm')])

# %%
G.nodes
# Out:
# NodeView((1, 2, 3, 's', 'p', 'a', 'm'))

# %% [markdown]
# ### A.5 Accessing edges and neighbors

# %%
G

# %%
G[1]
# Out:
# AtlasView({2: {}})

# %%
G[3]
# Out:
# AtlasView({'m': {}})

# %%
G.add_edge(1, 3)

# %%
G[1][3]['color'] = "blue"

# %%
G.edges[3, 'm']['color'] = "read"

# %%
G.edges
# Out:
# EdgeView([(1, 2), (1, 3), (3, 'm')])

# %%
# Fast examination of all (node, adjacency) pairs is achieved using G.adjacency(), or G.adj.items().

# %%
FG = nx.Graph()
FG.add_weighted_edges_from([(1, 2, 0.125),(1, 3, 0.75), (2, 4, 1.2), (3, 4, 0.375)])

# %%
for n, nbrs in FG.adj.items():
    for nbr, eattr in nbrs.items():
        wt = eattr['weight']
        print('(%d, %d, %.3f)' % (n, nbr, wt))
# Out:
# (1, 2, 0.125)
# (1, 3, 0.750)
# (2, 1, 0.125)
# (2, 4, 1.200)
# (3, 1, 0.750)
# (3, 4, 0.375)
# (4, 2, 1.200)
# (4, 3, 0.375)

# %%
FG.adj.items()
# Out:
# ItemsView(AdjacencyView({1: {2: {'weight': 0.125}, 3: {'weight': 0.75}}, 2: {1: {'weight': 0.125}, 4: {'weight': 1.2}}, 3: {1: {'weight': 0.75}, 4: {'weight': 0.375}}, 4: {2: {'weight': 1.2}, 3: {'weight': 0.375}}}))

# %%
for n, nbrs in FG.adj.items():
    print(n, nbrs)
# Out:
# 1 {2: {'weight': 0.125}, 3: {'weight': 0.75}}
# 2 {1: {'weight': 0.125}, 4: {'weight': 1.2}}
# 3 {1: {'weight': 0.75}, 4: {'weight': 0.375}}
# 4 {2: {'weight': 1.2}, 3: {'weight': 0.375}}

# %%
nbrs # 这里是最后一组。
# Out:
# AtlasView({2: {'weight': 1.2}, 3: {'weight': 0.375}})

# %%
for nbr, eattr in nbrs.items():
    print(nbr, eattr)
# Out:
# 2 {'weight': 1.2}
# 3 {'weight': 0.375}

# %%
for n, nbrs in FG.adj.items():
    for nbr, eattr in nbrs.items():
        wt = eattr['weight']
        print(nbr, eattr)
        print('(%d, %d, %.3f)' % (n, nbr, wt))
        print('--------------------')
# Out:
# 2 {'weight': 0.125}
# (1, 2, 0.125)
# --------------------
# 3 {'weight': 0.75}
# (1, 3, 0.750)
# --------------------
# 1 {'weight': 0.125}
# (2, 1, 0.125)
# --------------------
# 4 {'weight': 1.2}
# (2, 4, 1.200)
# --------------------
# 1 {'weight': 0.75}
# (3, 1, 0.750)
# --------------------
# 4 {'weight': 0.375}
# (3, 4, 0.375)
# --------------------
# 2 {'weight': 1.2}
# (4, 2, 1.200)
# --------------------
# 3 {'weight': 0.375}
# (4, 3, 0.375)
# --------------------

# %%
#Convenient access to all edges is achieved with the edges property.
for (u, v, wt ) in FG.edges.data('weight'):
    print('(%d, %d, %.3f)' % (u, v, wt))
# Out:
# (1, 2, 0.125)
# (1, 3, 0.750)
# (2, 4, 1.200)
# (3, 4, 0.375)

# %%
FG.edges.data
# Out:
# <bound method OutEdgeView.data of EdgeView([(1, 2), (1, 3), (2, 4), (3, 4)])>

# %% [markdown]
# ### A.6 Adding attributes to graphs, nodes, and edges

# %%
#Assign graph attributes when creating a new graph
G = nx.Graph(day = 'Friday')

# %%
G.node.data
# Out:
# <bound method NodeView.data of NodeView(())>

# %% [markdown]
# #### A6.2 Node attributes

# %%
# >>> G.add_node(1, time='5pm')
# >>> G.add_nodes_from([3], time='2pm')
# >>> G.nodes[1]
# {'time': '5pm'}
# >>> G.nodes[1]['room'] = 714
# >>> G.nodes.data()
# NodeDataView({1: {'room': 714, 'time': '5pm'}, 3: {'time': '2pm'}})

# %% [markdown]
# #### A6.3 Edge attributes

# %%
# >>> G.add_edge(1, 2, weight=4.7 )
# >>> G.add_edges_from([(3, 4), (4, 5)], color='red')
# >>> G.add_edges_from([(1, 2, {'color': 'blue'}), (2, 3, {'weight': 8})])
# >>> G[1][2]['weight'] = 4.7
# >>> G.edges[3, 4]['weight'] = 4.2

# %% [markdown]
# ### A7 Directed graphs

# %%
DG = nx.Graph()

# %%
DG.add_weighted_edges_from([(1, 2, 0.5), (3, 1, 0.75)])

# %%
DG.edges
# Out:
# EdgeView([(1, 2), (1, 3)])

# %%
DG.nodes
# Out:
# NodeView((1, 2, 3))

# %%
a = list(nx.connected_component_subgraphs(DG))

# %%
a

# %%
b = list(nx.connected_components(DG))

# %%
b
# Out:
# [{1, 2, 3}]

# %%
DG.nodes
# Out:
# NodeView((1, 2, 3))

# %%
undirected = nx.to_undirected(DG)
undirected

# %%
undirected.edges()
# Out:
# EdgeView([(1, 2), (1, 3)])

# %%
undirected.nodes
# Out:
# NodeView((1, 2, 3))

# %% [markdown]
# ### A9 Graph generators and graph operations

# %% [markdown]
# ### A10 Analyzing Graph

# %%
G = nx.Graph()

# %%
G.add_edges_from([(1, 2), (1, 3)])
G.add_node("spam")

# %%
# 找出所有相连的节点
list(nx.connected_components(G))
# Out:
# [{1, 2, 3}, {'spam'}]

# %%
sorted(d for n, d in G.degree())
# Out:
# [0, 1, 1, 2]

# %%
nx.clustering(G)
# Out:
# {1: 0, 2: 0, 3: 0, 'spam': 0}

# %%
sp = dict(nx.all_pairs_node_connectivity(G))
sp
# Out:
# {1: {2: 1, 3: 1, 'spam': 0},
#  2: {1: 1, 3: 1, 'spam': 0},
#  3: {1: 1, 2: 1, 'spam': 0},
#  'spam': {1: 0, 2: 0, 3: 0}}

# %%
a = list(G.nodes)
a
# Out:
# [1, 2, 3, 'spam']

# %%
# for i in a :
    
#     neighbor = nx.all_neighbors(G, i)

# %%
import matplotlib.pyplot as plt

# %%
a = [(152, 193), (56, 60), (56, 57), (56, 58), (60, 193), (60, 61), (59, 57), (62, 61), (153, 193), (64, 193)]

# %%
# G11 = nx.petersen_graph()

# %%
# G11.add_edges_from(a)

# %%
# nx.draw(G11, with_labels=True, font_weight='bold')

# %%
# G11.edges

# %%
# G11.nodes

# %%
b = [(152, 193), (56, 60), (56, 57), (56, 58), (60, 193), (60, 61), (59, 58), (62, 61), (153, 193), (64, 193)]

# %%
G12 = nx.Graph()

# %%
G12.add_edges_from([(188, 187)])

# %%
nx.draw(G12, with_labels=True, font_weight='bold')

# %%
G12.nodes
# Out:
# NodeView((188, 187))

# %%
aaa = [{109: {108: {'weight': 0}, 1: {'weight': 0}}}, {13: {112: {'weight': 0}}, 113: {13: {'weight': 0}, 110: {'weight': 0}, 14: {'weight': 0}}, 10: {11: {'weight': 0}}, 110: {10: {'weight': 0}, 8: {'weight': 0}, 6: {'weight': 0}, 5: {'weight': 0}}, 5: {4: {'weight': 0}}, 8: {111: {'weight': 0}}}, {18: {17: {'weight': 0}}, 116: {18: {'weight': 0}}, 115: {114: {'weight': 0}}, 17: {115: {'weight': 0}}}, {27: {123: {'weight': 0}}, 126: {124: {'weight': 0}, 27: {'weight': 0}, 121: {'weight': 0}, 125: {'weight': 0}}, 122: {25: {'weight': 0}}, 121: {122: {'weight': 0}, 119: {'weight': 0}, 120: {'weight': 0}, 118: {'weight': 0}}, 118: {117: {'weight': 0}}}, {188: {187: {'weight': 0}}}, {37: {134: {'weight': 0}}, 137: {135: {'weight': 0}, 37: {'weight': 0}, 132: {'weight': 0}, 136: {'weight': 0}}, 34: {35: {'weight': 0}}, 132: {34: {'weight': 0}, 131: {'weight': 0}, 32: {'weight': 0}, 128: {'weight': 0}, 189: {'weight': 0}}, 189: {127: {'weight': 0}, 186: {'weight': 0}}, 32: {129: {'weight': 0}}, 131: {130: {'weight': 0}}}, {143: {141: {'weight': 0}, 142: {'weight': 0}, 41: {'weight': 0}}, 139: {138: {'weight': 0}}, 140: {138: {'weight': 0}}, 41: {139: {'weight': 0}, 140: {'weight': 0}}}, {191: {144: {'weight': 0}, 44: {'weight': 0}, 51: {'weight': 0}, 145: {'weight': 0}}, 45: {47: {'weight': 0}}, 46: {47: {'weight': 0}}, 48: {49: {'weight': 0}}, 44: {45: {'weight': 0}, 46: {'weight': 0}, 48: {'weight': 0}}}, {151: {54: {'weight': 0}, 150: {'weight': 0}, 148: {'weight': 0}, 192: {'weight': 0}}, 150: {149: {'weight': 0}}}, {193: {152: {'weight': 0}, 60: {'weight': 0}, 64: {'weight': 0}, 153: {'weight': 0}}, 60: {56: {'weight': 0}, 61: {'weight': 0}}, 57: {59: {'weight': 0}}, 58: {59: {'weight': 0}}, 61: {62: {'weight': 0}}, 56: {57: {'weight': 0}, 58: {'weight': 0}}}, {155: {67: {'weight': 0}, 66: {'weight': 0}}}, {71: {70: {'weight': 0}, 185: {'weight': 0}}}, {73: {74: {'weight': 0}, 72: {'weight': 0}}, 75: {76: {'weight': 0}}, 72: {75: {'weight': 0}}}, {161: {162: {'weight': 0}}, 195: {161: {'weight': 0}, 159: {'weight': 0}, 194: {'weight': 0}, 79: {'weight': 0}, 78: {'weight': 0}}, 79: {157: {'weight': 0}, 156: {'weight': 0}}, 78: {77: {'weight': 0}}, 159: {158: {'weight': 0}}}, {166: {163: {'weight': 0}, 164: {'weight': 0}, 165: {'weight': 0}, 85: {'weight': 0}, 84: {'weight': 0}}, 84: {83: {'weight': 0}}}, {169: {167: {'weight': 0}, 170: {'weight': 0}, 168: {'weight': 0}, 89: {'weight': 0}}, 89: {88: {'weight': 0}}}, {176: {175: {'weight': 0}}, 196: {176: {'weight': 0}}, 173: {172: {'weight': 0}}, 174: {173: {'weight': 0}}, 175: {174: {'weight': 0}}}, {181: {101: {'weight': 0}, 100: {'weight': 0}, 180: {'weight': 0}}, 180: {179: {'weight': 0}}}, {184: {104: {'weight': 0}, 183: {'weight': 0}}, 183: {182: {'weight': 0}}}]
final_rsult = []
for item in aaa:
    result = []
    for key in item:
        for sub_item in item[key] :
            result.append((key,sub_item))
    final_rsult.append(result)

# %%
final_rsult
# Out:
# [[(109, 108), (109, 1)],
#  [(13, 112),
#   (113, 13),
#   (113, 110),
#   (113, 14),
#   (10, 11),
#   (110, 10),
#   (110, 8),
#   (110, 6),
#   (110, 5),
#   (5, 4),
#   (8, 111)],
#  [(18, 17), (116, 18), (115, 114), (17, 115)],
#  [(27, 123),
#   (126, 124),
#   (126, 27),
#   (126, 121),
#   (126, 125),
#   (122, 25),
#   (121, 122),
#   (121, 119),
#   (121, 120),
#   (121, 118),
#   (118, 117)],
#  [(188, 187)],
#  [(37, 134),
#   (137, 135),
#   (137, 37),
#   (137, 132),
#   (137, 136),
#   (34, 35),
#   (132, 34),
#   (132, 131),
#   (132, 32),
#   (132, 128),
#   (132, 189),
#   (189, 127),
#   (189, 186),
#   (32, 129),
#   (131, 130)],
#  [(143, 141),
#   (143, 142),
#   (143, 41),
#   (139, 138),
#   (140, 138),
#   (41, 139),
#   (41, 140)],
#  [(191, 144),
#   (191, 44),
#   (191, 51),
#   (191, 145),
#   (45, 47),
#   (46, 47),
#   (48, 49),
#   (44, 45),
#   (44, 46),
#   (44, 48)],
#  [(151, 54), (151, 150), (151, 148), (151, 192), (150, 149)],
#  [(193, 152),
# ...

# %%
G12 = nx.Graph()
G12.add_edges_from(final_rsult[9])
nx.draw(G12, with_labels=True, font_weight='bold')

# %%
G12 = nx.Graph()
G12.add_edges_from([(152, 193), (56, 60), (56, 57), (56, 58), (60, 193), (60, 61), (59, 57), (62, 61), (153, 193), (64, 193)])
nx.draw(G12, with_labels=True, font_weight='bold')

# %%
a123 =[(174, 175),(174, 77),(174, 78),(174, 80),(175, 85),(176, 85),(177, 85),(178, 85),(76, 77),(76, 78),(76, 79),(77, 173),(77, 82),(78, 173),(78, 82),(79, 80),(80, 173),(80, 82),(81, 173),(81, 82)]

# %%
G123 = nx.Graph()

# %%
G123.add_edges_from(a123)

# %%
nx.draw(G123, with_labels=True, font_weight='bold')

# %%
# 生成矢量图
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
a1234= [(108, 109),(108, 110),(108, 111),(109, 114),(109, 198),(110, 114),(110, 198),(111, 112),(112, 114),(112, 198),(113, 114),(113, 198)]

# %%
G1234 = nx.Graph()
G1234.add_edges_from(a1234)
nx.draw(G1234, with_labels=True, font_weight='bold')

# %%
import networkx as nx

# %% [markdown]
# ### 尝试生成有向图

# %%
g_directed = nx.DiGraph(directed = True) #导入有向图，注意

# %%
a12345 = [(108, 109),(108, 110),(108, 111),(109, 114),(109, 198),(110, 114),(110, 198),(111, 112),(112, 114),(112, 198),(113, 114),(113, 198)]

# %%
g_directed.add_edges_from(a12345)

# %%
nx.draw(g_directed, with_labels=True, font_weight='bold')

# %%
a123 =[(174, 175),(174, 77),(174, 78),(174, 80),(175, 85),(176, 85),(177, 85),(178, 85),(76, 77),(76, 78),(76, 79),(77, 173),(77, 82),(78, 173),(78, 82),(79, 80),(80, 173),(80, 82),(81, 173),(81, 82)]
g_directed_2 = nx.DiGraph(directed = True) #导入有向图，注意
g_directed_2.add_edges_from(a123)

# %%
nx.draw(g_directed_2, with_labels=True, font_weight='bold')

# %%
nx.draw_networkx(g_directed_2, with_labels=True, font_weight='bold', font_size= 8, node_size=150,arrowsize=5,linewidths=1, width= 0.5 )

# %%
plt.figure(1,figsize=(12,12)) 
nx.draw_networkx(g_directed_2, with_labels=True, font_weight='bold', font_size= 8, node_size=150,arrowsize=5,linewidths=1, width= 0.5)

# %% [markdown]
# ### 画布太小，尝试修改

# %%
import matplotlib.pyplot as plt
import networkx as nx
G = nx.cycle_graph(80)
pos = nx.circular_layout(G)
# default
plt.figure(1)
nx.draw(G,pos)
# smaller nodes and fonts
plt.figure(2)
nx.draw(G,pos,node_size=60,font_size=8) 
# larger figure size
plt.figure(3,figsize=(12,12)) 
nx.draw(G,pos)
plt.show()

# %% [markdown]
# ### 尝试合并节点  176 - 178

# %%
M = nx.contracted_nodes(g_directed_2, 176, 178 ) # 合并2个节点，写在前面的那个节点保留下来。

# %%
plt.figure(1,figsize=(12,12)) 
nx.draw_networkx(M, with_labels=True, font_weight='bold', font_size= 8, node_size=150,arrowsize=5,linewidths=1, width= 0.5)
# 注意看，178 已经消失了~ ！
